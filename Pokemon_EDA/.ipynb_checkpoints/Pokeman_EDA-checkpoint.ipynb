# %% [markdown]
# # Import data manipulation and visualization libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Loading the Pokemon dataset

# %%
df_raw = pd.read_csv("pokemon.csv")
df_raw
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %% [markdown]
# # Create a copy of the raw dataset for manipulation

# %%
df = df_raw.copy()
df.tail()
# Out:
#        #                 Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 795  719              Diancie     Rock  Fairy    600  50     100      150
# 796  719  DiancieMega Diancie     Rock  Fairy    700  50     160      110
# 797  720  HoopaHoopa Confined  Psychic  Ghost    600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic   Dark    680  80     160       60
# 799  721            Volcanion     Fire  Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True

# %%
# Checking the dimensions of the dataset (rows, columns)
df.shape
# Out:
# (800, 13)

# %%
# Geting information about the dataset (data types, non-null values)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %%
# Geting the column names of the dataset
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
# Geting descriptive statistics of numerical features
df.describe().round(2)
# Out:
#             #   Total      HP  Attack  Defense  Sp. Atk  Sp. Def   Speed  \
# count  800.00  800.00  800.00  800.00   800.00   800.00   800.00  800.00
# mean   362.81  435.10   69.26   79.00    73.84    72.82    71.90   68.28
# std    208.34  119.96   25.53   32.46    31.18    32.72    27.83   29.06
# min      1.00  180.00    1.00    5.00     5.00    10.00    20.00    5.00
# 25%    184.75  330.00   50.00   55.00    50.00    49.75    50.00   45.00
# 50%    364.50  450.00   65.00   75.00    70.00    65.00    70.00   65.00
# 75%    539.25  515.00   80.00  100.00    90.00    95.00    90.00   90.00
# max    721.00  780.00  255.00  190.00   230.00   194.00   230.00  180.00
#
#        Generation
# count      800.00
# mean         3.32
# std          1.66
# min          1.00
# 25%          2.00
# 50%          3.00
# 75%          5.00
# max          6.00

# %%
# Geting descriptive statistics of categorical and boolean features
df.describe(include=("O","bool"))
# Out:
#              Name Type 1  Type 2 Legendary
# count         800    800     414       800
# unique        800     18      18         2
# top     Bulbasaur  Water  Flying     False
# freq            1    112      97       735

# %%
# Checking for duplicate Pokemon names
df[df["Name"].duplicated()]
# Out:
# Empty DataFrame
# Columns: [#, Name, Type 1, Type 2, Total, HP, Attack, Defense, Sp. Atk, Sp. Def, Speed, Generation, Legendary]
# Index: []

# %%
# Checking for completely duplicate rows
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [#, Name, Type 1, Type 2, Total, HP, Attack, Defense, Sp. Atk, Sp. Def, Speed, Generation, Legendary]
# Index: []

# %%
# Filling missing values in 'Type 2' column with 'None'
df["Type 2"].fillna(value="None",inplace=True)
df.sample() # Display a random sample of rows
# Out:
#      #    Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 17  14  Kakuna    Bug  Poison    205  45      25       50       25       25
#
#     Speed  Generation  Legendary
# 17     35           1      False

# %%
# Counting the number of non-null values in each column
df.count()
# Out:
# #             800
# Name          800
# Type 1        800
# Type 2        800
# Total         800
# HP            800
# Attack        800
# Defense       800
# Sp. Atk       800
# Sp. Def       800
# Speed         800
# Generation    800
# Legendary     800
# dtype: int64

# %%
# Converting column names to lowercase
df.columns=df.columns.str.lower()
df.columns
# Out:
# Index(['#', 'name', 'type 1', 'type 2', 'total', 'hp', 'attack', 'defense',
#        'sp. atk', 'sp. def', 'speed', 'generation', 'legendary', 'Num'],
#       dtype='object')

# %%
# Clean and standardize column names
cols=[]
for i in df.columns:
    if " " in i:
        i=i.replace(" ","_")
    if "." in i:
        i=i.replace(".","")
    elif "#" == i:
        i = "Num"
    cols.append(i)
df.columns=cols
df.columns
# Out:
# Index(['Num', 'name', 'type_1', 'type_2', 'total', 'hp', 'attack', 'defense',
#        'sp_atk', 'sp_def', 'speed', 'generation', 'legendary'],
#       dtype='object')

# %% [markdown]
# # Explore unique values in categorical columns

# %%
df["type_1"].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %%
df["type_2"].unique()
# Out:
# array(['Poison', 'None', 'Flying', 'Dragon', 'Ground', 'Fairy', 'Grass',
#        'Fighting', 'Psychic', 'Steel', 'Ice', 'Rock', 'Dark', 'Water',
#        'Electric', 'Fire', 'Ghost', 'Bug', 'Normal'], dtype=object)

# %%
df["generation"].unique()
# Out:
# array([1, 2, 3, 4, 5, 6], dtype=int64)

# %% [markdown]
# # Count the occurrences of each Pokemon type

# %%
df["type_1"].value_counts()
# Out:
# type_1
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Dragon       32
# Ground       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: count, dtype: int64

# %%
df["type_2"].value_counts()
# Out:
# type_2
# None        386
# Flying       97
# Ground       35
# Poison       34
# Psychic      33
# Fighting     26
# Grass        25
# Fairy        23
# Steel        22
# Dark         20
# Dragon       18
# Ice          14
# Rock         14
# Water        14
# Ghost        14
# Fire         12
# Electric      6
# Normal        4
# Bug           3
# Name: count, dtype: int64

# %%
df["generation"].value_counts()
# Out:
# generation
# 1    166
# 5    165
# 3    160
# 4    121
# 2    106
# 6     82
# Name: count, dtype: int64

# %% [markdown]
# # Count the occurrences of legendary Pokemon

# %%
df["legendary"].value_counts(dropna=False)
# Out:
# legendary
# False    735
# True      65
# Name: count, dtype: int64

# %% [markdown]
# # Query and filter the dataset based on conditions

# %%
df.query("generation == 1 & legendary == True") # Legendary Pokemon from generation 1
# Out:
#      Num                 name    type_1    type_2  total   hp  attack  \
# 156  144             Articuno       Ice    Flying    580   90      85
# 157  145               Zapdos  Electric    Flying    580   90      90
# 158  146              Moltres      Fire    Flying    580   90     100
# 162  150               Mewtwo   Psychic      None    680  106     110
# 163  150  MewtwoMega Mewtwo X   Psychic  Fighting    780  106     190
# 164  150  MewtwoMega Mewtwo Y   Psychic      None    780  106     150
#
#      defense  sp_atk  sp_def  speed  generation  legendary
# 156      100      95     125     85           1       True
# 157       85     125      90    100           1       True
# 158       90     125      85     90           1       True
# 162       90     154      90    130           1       True
# 163      100     154     100    130           1       True
# 164       70     194     120    140           1       True

# %%
df.query("generation==2 & legendary == True")["speed"] # Speed of legendary Pokemon from generation 2
# Out:
# 262    115
# 263    100
# 264     85
# 269    110
# 270     90
# Name: speed, dtype: int64

# %%
df.query("legendary == True") # All legendary Pokemon
# Out:
#      Num                 name    type_1    type_2  total   hp  attack  \
# 156  144             Articuno       Ice    Flying    580   90      85
# 157  145               Zapdos  Electric    Flying    580   90      90
# 158  146              Moltres      Fire    Flying    580   90     100
# 162  150               Mewtwo   Psychic      None    680  106     110
# 163  150  MewtwoMega Mewtwo X   Psychic  Fighting    780  106     190
# ..   ...                  ...       ...       ...    ...  ...     ...
# 795  719              Diancie      Rock     Fairy    600   50     100
# 796  719  DiancieMega Diancie      Rock     Fairy    700   50     160
# 797  720  HoopaHoopa Confined   Psychic     Ghost    600   80     110
# 798  720   HoopaHoopa Unbound   Psychic      Dark    680   80     160
# 799  721            Volcanion      Fire     Water    600   80     110
#
#      defense  sp_atk  sp_def  speed  generation  legendary
# 156      100      95     125     85           1       True
# ...

# %% [markdown]
# # Calculate and analyze statistical measures

# %%
# Calculate the man of the 'total' column
total_mean = df.total.mean()
total_mean
# Out:
# 435.1025

# %%
df["total"].median() #Calculate the median of the 'total' column
# Out:
# 450.0

# %%
# Calculate the mode of the 'total' column
df["total"].mode()
# Out:
# 0    600
# Name: total, dtype: int64

# %%
# Filter Pokemon with total stats greater than a threshold
df.query("total > 435.1025")
# Out:
#      Num                       name   type_1  type_2  total  hp  attack  \
# 2      3                   Venusaur    Grass  Poison    525  80      82
# 3      3      VenusaurMega Venusaur    Grass  Poison    625  80     100
# 6      6                  Charizard     Fire  Flying    534  78      84
# 7      6  CharizardMega Charizard X     Fire  Dragon    634  78     130
# 8      6  CharizardMega Charizard Y     Fire  Flying    634  78     104
# ..   ...                        ...      ...     ...    ...  ..     ...
# 795  719                    Diancie     Rock   Fairy    600  50     100
# 796  719        DiancieMega Diancie     Rock   Fairy    700  50     160
# 797  720        HoopaHoopa Confined  Psychic   Ghost    600  80     110
# 798  720         HoopaHoopa Unbound  Psychic    Dark    680  80     160
# 799  721                  Volcanion     Fire   Water    600  80     110
#
#      defense  sp_atk  sp_def  speed  generation  legendary
# ...

# %%
# Get the maximum speed value
df["speed"].max()
# Out:
# 180

# %%
# Get the index of the Pokemon with the maximum speed
df.speed.idxmax()
# Out:
# 431

# %%
# Get the row of the Pokemon with the maximum speed
df.loc[[df["speed"].idxmax()]]
# Out:
#      Num               name   type_1 type_2  total  hp  attack  defense  \
# 431  386  DeoxysSpeed Forme  Psychic   None    600  50      95       90
#
#      sp_atk  sp_def  speed  generation  legendary
# 431      95      90    180           3       True

# %%
# Get the row of the Pokemon with the maximum total stats
df.loc[[df["total"].idxmax()]]
# Out:
#      Num                 name   type_1    type_2  total   hp  attack  defense  \
# 163  150  MewtwoMega Mewtwo X  Psychic  Fighting    780  106     190      100
#
#      sp_atk  sp_def  speed  generation  legendary
# 163     154     100    130           1       True

# %% [markdown]
# ## Visualization

# %% [markdown]
# # Create a countplot of Pokemon types

# %%
sns.catplot(y="type_1",data=df,kind="count",order=df["type_1"].value_counts().index,aspect=2).fig.suptitle("count of type1 pokemon",y=1.0,color="red")
# Out:
# Text(0.5, 1.0, 'count of type1 pokemon')

# %%
sns.catplot(x="type_2",data=df,kind="count",order=df["type_2"].value_counts().index,aspect=2).fig.suptitle("Count of tyoe2 pokemon",y=1,color="purple")
# Out:
# Text(0.5, 1, 'Count of tyoe2 pokemon')

# %% [markdown]
# # Create a countplot of Pokemon generations with annotations

# %%
ax=sns.countplot(x="generation",data=df)
for i in ax.patches:
    x=i.get_x()
    y=i.get_height()/2
    ax.annotate(y,(x+0.2,y))

# %% [markdown]
# ## Visualization for generation and Legendry Counts

# %%
sns.catplot(x="generation",data=df,kind="count",hue="legendary").fig.suptitle("Count of Lengendry Pokemon",y=1.03)
plt.show()

# %%
ax=sns.countplot(x="legendary",data=df,color="yellow",width=0.5)
for i in ax.patches:
    x=i.get_x()
    y=i.get_height()
    ax.annotate(y,(x+0.2,y/2),color="red",ha="center")# ha=horigentally aligned
ax.set_title("Count of Legendry",color="blue")
# Out:
# Text(0.5, 1.0, 'Count of Legendry')

# %% [markdown]
# # Distributin of Total powers of pokemons

# %%
sns.kdeplot(x="total",data=df).set_title("Distribution of Total values of pokemon",color="green")
# Out:
# Text(0.5, 1.0, 'Distribution of Total values of pokemon')

# %%
sns.histplot(x="hp",data=df,bins=20,color="green").set_title("Distribution of hp of pokemon",color='red')
# Look at the 250 value where it comes under the outlier
# Out:
# Text(0.5, 1.0, 'Distribution of hp of pokemon')

# %% [markdown]
# # relation plots

# %%
sns.pairplot(df)

# %%
sns.heatmap(df[df["type_2"]!="none"].groupby(["type_1","type_2"]).size().unstack(),cmap="coolwarm")
# Out:
# <Axes: xlabel='type_2', ylabel='type_1'>
